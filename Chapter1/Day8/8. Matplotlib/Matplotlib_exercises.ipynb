# %% [markdown]
# # Matplotlib

# %% [markdown]
# For these exercises, we are using Pandas and Matplotlib to visualize Company Sales Data.
#
# We will be using the following dataset: https://pynative.com/wp-content/uploads/2019/01/company_sales_data.csv

# %% [markdown]
# ### Exercise 1: Read the Total profit of all months and show it using a line plot.
# Total profit data provided for each month. The enerated line plot must include the following properties:<br>
# - X label name = Month Number
# - Y label name = Total profit
#
# The line plot graph should look like this:
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Write your code here
url = 'https://pynative.com/wp-content/uploads/2019/01/company_sales_data.csv'

data = pd.read_csv("C:/Users/Hari/Desktop/Strive School/DS_Strive_HW/DS_oct_2021/Day8/8. Matplotlib/data/company_sales_data.csv")
data.head(5)

# Write your code here
fig= plt.figure(figsize=(10,6))
ax= fig.add_subplot(1,1,1)
#set x axis
xlabels = range(13)
ax.set_xlabel("Month number", fontsize=20)
ax.set_xticks(xlabels)
ax.set_xticklabels(xlabels, fontsize=20 )
#set y axis
ylabels = range(100000,600000,100000)
ax.set_ylabel("Total profit", fontsize=20)
ax.set_yticks(ylabels)
ax.set_yticklabels(ylabels, fontsize=20 )
ax.set_ylim(100000,500000)

ax.set_title("Company profit per month", fontsize=30)
ax.plot(data['month_number'],data['total_profit'])
plt.show()

# %% [markdown]
# ### Exercise 2: Get the Total profit of all months and show a line plot with the following Style properties:
# - Line Style dotted and Line color should be red
# - Show legend at the lower right location.
# - X label name = Month Number
# - Y label name = Sold units number
# - Add a circle marker.
# - Line marker color as read
# - Line width should be 3
#
# The line plot graph should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here

# Write your code here
fig= plt.figure(figsize=(10,6))
ax= fig.add_subplot(1,1,1)
#set x axis
xlabels = range(13)
ax.set_xlabel("Month number", fontsize=20)
ax.set_xticks(xlabels)
ax.set_xticklabels(xlabels, fontsize=20 )
#set y axis
ylabels = range(100000,600000,100000)
ax.set_ylabel("Sold units number", fontsize=20)
ax.set_yticks(ylabels)
ax.set_yticklabels(ylabels, fontsize=20 )
ax.set_ylim(100000,500000)

ax.set_title("Company profit per month", fontsize=30)
ax.plot(data['month_number'],data['total_profit'], color='red', linestyle='dashed', linewidth=3, marker='o',
     markerfacecolor='black', markersize=12, markeredgecolor='red')

ax.legend(["Profit data of last year"],loc='lower right',prop={'size': 20})

plt.show()

# %% [markdown]
# ### Exercise 3: Read all product sales data and show it using a multiline plot.
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product).
#
# The graph should look like this:
# ![image.png](attachment:image.png)

# %%
data.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
# Write your code here
# Write your code here

fig= plt.figure(figsize=(10,8))
ax= fig.add_subplot(1,1,1)
#set x axis
xlabels = range(13)
ax.set_xlabel("Month number", fontsize=20)
ax.set_xticks(xlabels)
ax.set_xticklabels(xlabels, fontsize=20 )
#set y axis
ylabels = [1000,2000,4000,6000,8000,10000,12000,15000,18000]
ax.set_ylabel("Sold units number", fontsize=20)
ax.set_yticks(ylabels)
ax.set_yticklabels(ylabels, fontsize=20 )
ax.set_ylim(0,18000)

ax.set_title("Sales data", fontsize=30)

ax.plot(data['month_number'],data['facecream'], color='b',linewidth=5, marker='o',
     markerfacecolor='b', markersize=12, markeredgecolor='b')
ax.plot(data['month_number'],data['facewash'], color='orange',linewidth=5, marker='o',
     markerfacecolor='orange', markersize=12, markeredgecolor='orange')
ax.plot(data['month_number'],data['toothpaste'], color='g',linewidth=5, marker='o',
     markerfacecolor='g', markersize=12, markeredgecolor='g')
ax.plot(data['month_number'],data['bathingsoap'], color='red',linewidth=5, marker='o',
     markerfacecolor='red', markersize=12, markeredgecolor='red')
ax.plot(data['month_number'],data['shampoo'], color='purple',linewidth=5, marker='o',
     markerfacecolor='purple', markersize=12, markeredgecolor='purple')
ax.plot(data['month_number'],data['moisturizer'], color='brown',linewidth=5, marker='o',
     markerfacecolor='brown', markersize=12, markeredgecolor='brown')

ax.legend(["Facecream Sales Data","Facewash Sales Data","Toothpaste Sales Data",\
           "Bathingsoap Sales Data","Shampoo Sales Data","Moisturizer Sales Data"],loc='upper left',prop={'size': 20})

plt.show()

# %% [markdown]
# ### Exercise 4: Read the toothpaste sales data of each month and show it using a scatter plot.
# Also, add a grid in the plot (the grid line style should be “–“).
#
# The scatter plot should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
fig= plt.figure(figsize=(10,6))
ax= fig.add_subplot(1,1,1)
#set x axis
xlabels = range(13)
ax.set_xlabel("Month number", fontsize=20)
ax.set_xticks(xlabels)
ax.set_xticklabels(xlabels, fontsize=20 )
#set y axis
ylabels = range(4500,8500,500)
ax.set_ylabel("Number of units sold", fontsize=20)
ax.set_yticks(ylabels)
ax.set_yticklabels(ylabels, fontsize=20 )
#ax.set_ylim(4500,8000)

ax.set_title("Tooth paste sales data", fontsize=30)
ax.scatter(data['month_number'],data['toothpaste'], s=150 )

ax.legend(["Toothpaste Sales Data"],loc='upper left',prop={'size': 20})
ax.grid(linestyle='--', linewidth=2)
plt.show()

# %% [markdown]
# ### Exercise 5: Read the face cream and facewash product sales data and show it using the bar chart.
# The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.
#
# The bar chart should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
fig= plt.figure(figsize=(10,6))
ax= fig.add_subplot(1,1,1)
#set x axis
xlabels = range(13)
ax.set_xlabel("Month number", fontsize=20)
ax.set_xticks(xlabels)
ax.set_xticklabels(xlabels, fontsize=20 )
#set y axis
ylabels = range(0,4000,500)
ax.set_ylabel("Sales units in number", fontsize=20)
ax.set_yticks(ylabels)
ax.set_yticklabels(ylabels, fontsize=20 )
ax.set_ylim(0,4000)

ax.set_title("Facewash and facecream sales data", fontsize=30)
ax.bar(data['month_number']-0.15,data['facecream'] ,width=0.3)
ax.bar(data['month_number']+0.15,data['facewash'],color= 'orange',width=0.3)


ax.legend(["Facecream Sales Data","Facewash Sales Data"],loc='upper left',prop={'size': 20})
ax.grid(linestyle='--', linewidth=2)
plt.show()

# %% [markdown]
# ### Exercise 6: Read the sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk.
# The bar chart should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
fig= plt.figure(figsize=(10,6))
ax= fig.add_subplot(1,1,1)
#set x axis
xlabels = range(13)
ax.set_xlabel("Month number", fontsize=20)
ax.set_xticks(xlabels)
ax.set_xticklabels(xlabels, fontsize=20 )
#set y axis
ylabels = range(0,16000,2000)
ax.set_ylabel("Sales units in number", fontsize=20)
ax.set_yticks(ylabels)
ax.set_yticklabels(ylabels, fontsize=20 )
ax.set_ylim(0,15000)

ax.set_title("Bathingsoap Sales Data", fontsize=30)
ax.bar(data['month_number'],data['bathingsoap'] ,width=0.8)

ax.grid(linestyle='--', linewidth=2)
fig.savefig(f'{ax.get_title()}.png')

# %% [markdown]
# ### Exercise 7: Read the total profit of each month and show it using the histogram to see the most common profit ranges.
# The histogram should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
fig= plt.figure(figsize=(10,6))
ax= fig.add_subplot(1,1,1)
#set x axis
xlabels = [150000,175000,200000,225000,250000,300000,350000]
ax.set_xlabel("Profit range in dollars", fontsize=10)
ax.set_xticks(xlabels)
ax.set_xticklabels(xlabels, fontsize=10 )
#ax.set_xlim(125000,375000)
#set y axis
ax.set_ylabel("Actual profit in dollar", fontsize=10)
ylabels = range(0,6,1)
ax.set_yticks(ylabels)
ax.set_yticklabels(ylabels, fontsize=10 )
ax.set_ylim(0,5.25)

ax.set_title("Profit Data", fontsize=20)
ax.hist(data['total_profit'])
ax.legend(["Profit Data"],loc='upper left',prop={'size': 20})

# %% [markdown]
# ### Exercise 8: Calculate the total sale data for last year for each product and show it using a Pie chart.
# Note: In the Pie chart you should display the Number of units sold per year for each product in percentage.
#
# The Pie chart should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
fig= plt.figure(figsize=(15,10))
ax= fig.add_subplot(1,1,1)

labels = ["Facecream","Facewash","Toothpaste","Bathingsoap","Shampoo","Moisturizer"]

ax.set_title("Sales Data", fontsize=20)
ax.pie([data["facecream"].sum(),data["facewash"].sum(),data["toothpaste"].sum(),\
        data["bathingsoap"].sum(),data["shampoo"].sum(),data["moisturizer"].sum(),], normalize = True, \
      labels = labels, autopct=lambda p: '{:.1f}%'.format(p),textprops={'fontsize': 18})

ax.legend(labels,loc='lower right',prop={'size': 20})

# %% [markdown]
# ### Exercise 9: Read the Bathing soap facewash of all months and display it using the Subplot.
# The Subplot should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
fig= plt.figure(figsize=(10,8))

#FIRST PLOT

ax= fig.add_subplot(2,1,1)
#set x axis
ax.get_xaxis().set_visible(False) #an other option: ax1.set_xticks([])
#set y axis
ylabels = range(7500,13000,2500)
ax.set_yticks(ylabels)
ax.set_yticklabels(ylabels, fontsize=20 )

ax.set_title("Sales data of a bathing soap", fontsize=30)

ax.plot(data['month_number'],data['bathingsoap'], color='black',linewidth=5, marker='o',
     markerfacecolor='black', markersize=12, markeredgecolor='black')

#SECOND PLOT

ax= fig.add_subplot(2,1,2)
#set x axis
xlabels = range(13)
ax.set_xlabel("Month number", fontsize=20)
ax.set_xticks(xlabels)
ax.set_xticklabels(xlabels, fontsize=20 )
#set y axis
ylabels = [1500,2000]
ax.set_ylabel("Sold units number", fontsize=20)
ax.set_yticks(ylabels)
ax.set_yticklabels(ylabels, fontsize=20 )

ax.set_title("Sales data of a facewash", fontsize=30)

ax.plot(data['month_number'],data['facewash'], color='r',linewidth=5, marker='o',
     markerfacecolor='r', markersize=12, markeredgecolor='r')

plt.show()

# %% [markdown]
# ### Exercise 10: Read all product sales data and show it using the stack plot.
# The Stack plot should look like this:
# ![image.png](attachment:image.png)

# %%
data.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
# Write your code here
labels = ["facecream","facewash","toothpaste","bathingsoap","shampoo","moisturizer"]

fig= plt.figure(figsize=(10,6))
ax = fig.add_subplot(1,1,1)

#set x axis
xlabels = range(13)
ax.set_xlabel("Month number", fontsize=20)
ax.set_xticks(xlabels)
ax.set_xticklabels(xlabels, fontsize=20 )
#set y axis
ax.set_ylabel("Sales Units in Number", fontsize=20)
ylabels = range(0,32000,5000)
ax.set_yticks(ylabels)
ax.set_yticklabels(ylabels, fontsize=20 )

ax.set_title("Profit Data", fontsize=20)
data.iloc[:,:-2].plot.area(stacked=True,ax=ax, x="month_number", \
                           color=('#bf00bf','#00bfbf','#ff0000','#000000','#008000','#bfbf00'))

ax.legend(labels,loc='upper left',prop={'size': 10})
