# %%
import requests
page = requests.get("https://forecast.weather.gov/MapClick.php?x=276&y=148&site=lox&zmx=&zmy=&map_x=276&map_y=148#.YYJ4hWDP23A")
page
# Out:
# <Response [200]>

# %%
print(page.status_code)
page.content
# Out:
# 200
# ...
